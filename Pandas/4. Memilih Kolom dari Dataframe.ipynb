# %%
import pandas as pd

# %%
df_hasil_ujian = pd.read_csv("StudentsPerformance.csv")
df_hasil_ujian.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## 1. Memilih Satu Kolom

# %%
# Memilih kolom menggunakan [] (cara yang disarankan untuk memilih kolom)
df_hasil_ujian["gender"]

# %%
# Memeriksa tipe data sebuah kolom
type(df_hasil_ujian["gender"])

# %%
# Series: atribut dan metode yang tersedia
df_hasil_ujian["gender"].index
df_hasil_ujian["gender"].head()

# %% [markdown]
# ## 2. Memilih Dua atau Lebih Kolom dari Dataframe

# %%
# Memilih 2 kolom menggunakan [[]]
df_hasil_ujian[["gender", "math score"]]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# Memeriksa tipe data hasil seleksi
type(df_hasil_ujian[["gender", "math score"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# Memilih 2 atau lebih kolom menggunakan [[]]
df_hasil_ujian[["gender","writing score", "math score","reading score"]]
# Out:
#      gender  writing score  math score  reading score
# 0    female             74          72             72
# 1    female             88          69             90
# 2    female             93          90             95
# 3      male             44          47             57
# 4      male             75          76             78
# ..      ...            ...         ...            ...
# 995  female             95          88             99
# 996    male             55          62             55
# 997  female             65          59             71
# 998  female             77          68             78
# 999  female             86          77             86
#
# [1000 rows x 4 columns]
